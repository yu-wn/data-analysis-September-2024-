# %%
# 手すりセンサのデータで非階層型クラスタリング(DTWを利用)
#データのまとめ（ファイル作成）
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
import os
import glob
from tslearn.clustering import TimeSeriesKMeans
from tslearn.utils import to_time_series_dataset
from collections import defaultdict
from sklearn.metrics import silhouette_samples

# 関連ファイルの選択(3つのファイルの読み込みと結合)
datalist1 = glob.glob("C:\\Users\\miyazakipc\\Desktop\\2024年9月10日　実験\\てすりとキネクト（てすり）\\1回目変換後\\平滑、正規化後1回目データ\\抽出後データ\\*_force1_s1_normed_extracted.csv")
datalist2 = glob.glob("C:\\Users\\miyazakipc\\Desktop\\2024年9月10日　実験\\てすりとキネクト（てすり）\\2回目変換後\\平滑、正規化後2回目データ\\抽出後データ\\*_force2_s1_normed_extracted.csv")
datalist3 = glob.glob("C:\\Users\\miyazakipc\\Desktop\\2024年9月10日　実験\\てすりとキネクト（てすり）\\3回目変換後\\平滑、正規化後3回目データ\\抽出後データ\\*_force3_s1_normed_extracted.csv")


# データフレームのリストを初期化
df_list = []


# 各ファイルのデータを読み込み、横に結合してデータフレームに追加
for i in range(len(datalist1)):
    df1 = pd.read_csv(datalist1[i], header=None)
    df2 = pd.read_csv(datalist2[i], header=None)
    df3 = pd.read_csv(datalist3[i], header=None)

    # 横に結合
    df_combined = pd.concat([df1, df2, df3], axis=1)
    df_list.append(df_combined)

# 全てのデータフレームを1つのデータフレームに結合
datalist = pd.concat(df_list, axis=1)

# データフレームを表示
#print(datalist)

# 保存先ディレクトリの指定
save_path = r"C:\Users\miyazakipc\Desktop\2024年9月10日　実験\てすりとキネクト（てすり）\データ分析"

# 保存ファイル名の作成
output_file_name = os.path.join(save_path, "all_data.csv")

# データフレームをCSVファイルに保存
datalist.to_csv(output_file_name, index=True)
#ここまでで、抽出したデータを一つのファイルにまとめ保存している。 ここで、インデックスが重複してしまったため、以下で削除する。

# 保存先ディレクトリの指定
save_path = r"C:\\Users\\miyazakipc\\Desktop\\2024年9月10日　実験\\てすりとキネクト（てすり）\\データ分析\\all_data.csv"

# CSVファイルの読み込み
df = pd.read_csv(save_path, header=None)

# 最初の行を削除
df = df.drop(df.index[0])

# ファイルに再保存
df.to_csv(save_path, index=False, header=False)
#41×151のファイル
